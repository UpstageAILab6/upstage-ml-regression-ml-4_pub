# %%
# sys.path를 수정하여 모듈 경로를 설정
import sys
import os
import pandas as pd

# 프로젝트 루트 경로 추가
project_root = os.path.abspath("..")
sys.path.append(project_root)

import module

# %%
df = module.file_load.load_origin_train()
df_test = module.file_load.load_origin_test()

# %%
df = df.reset_index(drop=False)
df_test = df_test.reset_index(drop=False)

# %%
df.to_csv('../data/origin_train_index.csv', index=False)
df_test.to_csv('../data/origin_test_index.csv', index=False)
# Out:
#       index            시군구     번지     본번   부번      아파트명   전용면적(㎡)    계약년월  \
# 0         0  서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.9700  202307
# 1         1  서울특별시 강남구 개포동  651-1  651.0  1.0   개포더샵트리에  108.2017  202308
# 2         2  서울특별시 강남구 개포동    652  652.0  0.0    개포우성3차  161.0000  202307
# 3         3  서울특별시 강남구 개포동    652  652.0  0.0    개포우성3차  133.4600  202308
# 4         4  서울특별시 강남구 개포동    652  652.0  0.0    개포우성3차  104.4300  202308
# ...     ...            ...    ...    ...  ...       ...       ...     ...
# 9267   9267  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.6500  202307
# 9268   9268  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.6200  202307
# 9269   9269  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.6500  202308
# 9270   9270  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.9400  202309
# 9271   9271  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.6500  202309
#
#       계약일   층  ...  청소비관리형태      건축면적    주차대수 기타/의무/임대/임의=1/2/3/4  \
# 0      26   5  ...       직영   4858.00   262.0                  임의
# 1      15  10  ...       위탁   2724.46   305.0                  의무
# 2      28  15  ...       위탁  61064.24   419.0                  의무
# 3      10  14  ...       위탁  61064.24   419.0                  의무
# 4      18   6  ...       위탁  61064.24   419.0                  의무
# ...   ...  ..  ...      ...       ...     ...                 ...
# 9267   19  13  ...       위탁  14171.00  1568.0                  의무
# 9268   25  12  ...       위탁  14171.00  1568.0                  의무
# 9269   27  12  ...       위탁  14171.00  1568.0                  의무
# 9270    2  18  ...       위탁  14171.00  1568.0                  의무
# 9271    4  13  ...       위탁  14171.00  1568.0                  의무
#
#                       단지승인일 사용허가여부 관리비 업로드         좌표X        좌표Y  \
# 0     2022-11-17 13:00:29.0      Y       N  127.057210  37.476763
# 1     2022-02-23 13:01:10.0      Y       N  127.056394  37.484892
# 2     1984-12-22 00:00:00.0      Y       N  127.055990  37.483894
# 3     1984-12-22 00:00:00.0      Y       N  127.055990  37.483894
# 4     1984-12-22 00:00:00.0      Y       N  127.055990  37.483894
# ...                     ...    ...     ...         ...        ...
# 9267  2015-09-09 15:30:27.0      Y       N  127.106720  37.618870
# 9268  2015-09-09 15:30:27.0      Y       N  127.106720  37.618870
# 9269  2015-09-09 15:30:27.0      Y       N  127.106720  37.618870
# 9270  2015-09-09 15:30:27.0      Y       N  127.106720  37.618870
# 9271  2015-09-09 15:30:27.0      Y       N  127.106720  37.618870
#
#                       단지신청일
# 0     2022-11-17 10:19:06.0
# 1     2022-02-23 11:05:05.0
# 2     2013-03-07 09:46:28.0
# 3     2013-03-07 09:46:28.0
# 4     2013-03-07 09:46:28.0
# ...                     ...
# 9267  2014-09-01 13:05:03.0
# 9268  2014-09-01 13:05:03.0
# 9269  2014-09-01 13:05:03.0
# 9270  2014-09-01 13:05:03.0
# 9271  2014-09-01 13:05:03.0
#
# [9272 rows x 52 columns]
